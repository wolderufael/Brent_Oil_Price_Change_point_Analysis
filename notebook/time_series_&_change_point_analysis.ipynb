# %% [markdown]
# # Time Series and Change Point Analysis

# %% [markdown]
# ### Add project path to system path

# %%
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")
notebook_dir = os.getcwd()
parent_path=os.path.dirname(notebook_dir)

os.chdir(parent_path)

# %% [markdown]
# ### Import modules

# %%
from script.time_series_and_change_point_analysis import Analyzer
analyzer=Analyzer()

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.13.1

# %% [markdown]
# ### Load data

# %%
brent_oil_price_data=pd.read_csv("data/brent_oil_price_data.csv")

# %% [markdown]
# ## Time Series Analysis

# %%
analyzer.plot_time_series(brent_oil_price_data)

# %% [markdown]
# ## Change Point Analysis

# %% [markdown]
# ### CUSUM Method

# %%
analyzer.cusum_plot(brent_oil_price_data)

# %% [markdown]
# ## Bayesian Method
